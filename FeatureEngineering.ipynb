# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# %%
data = pd.read_csv('./datasets/trains.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data = pd.read_csv('./datasets/trains.csv')
#
# NameError: name 'pd' is not defined

# %%
data
# Out:
#       Unnamed: 0                         train_name train_number  \
# 0              0        Jammu Tawi Udhampur Special        04601
# 1              1                   JAT UDAHMPUR DMU        04603
# 2              3             UDHAMPUR JAMMUTAWI DMU        04604
# 3              4  Mumbai BandraT-Bikaner SF Special        04728
# 4              5    Sirsa - Hisar Passenger Special        04741
# ...          ...                                ...          ...
# 5202        5203    New Delhi Palwal Ladies Special        64492
# 5203        5204     Visakhapatnam Rajahmundry Pass        67296
# 5204        5205           Madgaon Karwar Passenger        70101
# 5205        5206            Danapur Giridih Express        83112
# 5206        5207               Tribeni Link Express        84369
#
#                       source destination  distance       total_time departure  \
# 0                 JAMMU TAWI    UDHAMPUR      53.0  0 days 01:35:00  10:40:00
# 1                 JAMMU TAWI    UDHAMPUR      53.0  0 days 01:35:00  16:15:00
# 2                   UDHAMPUR  JAMMU TAWI      53.0  0 days 01:30:00  18:20:00
# 3     MUMBAI BANDRA TERMINUS  BIKANER JN    1212.0  0 days 21:55:00  14:35:00
# 4                      Sirsa       Hisar      82.0  0 days 01:35:00  22:50:00
# ...                      ...         ...       ...              ...       ...
# 5202               NEW DELHI      PALWAL      56.0  0 days 01:30:00  17:50:00
# 5203           VISHAKAPATNAM  RAJAMUNDRY     201.0  0 days 05:15:00  18:10:00
# 5204                 MADGAON      KARWAR      82.0  0 days 01:20:00  19:00:00
# 5205                 DANAPUR     Giridih     298.0  0 days 09:30:00  19:00:00
# 5206             BARWADIH JN    BAREILLY     862.0  0 days 21:00:00  15:30:00
#
#        arrival
# 0     12:15:00
# 1     17:50:00
# 2     19:50:00
# 3     12:30:00
# 4     00:25:00
# ...        ...
# 5202  19:20:00
# 5203  23:25:00
# 5204  20:20:00
# 5205  04:30:00
# 5206  12:30:00
#
# [5207 rows x 9 columns]

# %%
X = data.drop('arrival', axis=1)
Y = data['arrival']

# %%
numeric_features = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_features = X.select_dtypes(include=['object', 'category']).columns.tolist()

# %%
# numeric_features
categorical_features
# Out:
# ['train_name',
#  'train_number',
#  'source',
#  'destination',
#  'total_time',
#  'departure']

# %%
# data.shape
data.describe()
# Out:
#         Unnamed: 0     distance
# count  5207.000000  5192.000000
# mean   2603.999616   544.864022
# std    1503.276422   696.824792
# min       0.000000     0.000000
# 25%    1302.500000    88.000000
# 50%    2604.000000   227.000000
# 75%    3905.500000   693.000000
# max    5207.000000  4279.000000

# %%
data = data.drop(columns=["Unnamed: 0"])
data
# Out:
#                              train_name train_number                  source  \
# 0           Jammu Tawi Udhampur Special        04601              JAMMU TAWI
# 1                      JAT UDAHMPUR DMU        04603              JAMMU TAWI
# 2                UDHAMPUR JAMMUTAWI DMU        04604                UDHAMPUR
# 3     Mumbai BandraT-Bikaner SF Special        04728  MUMBAI BANDRA TERMINUS
# 4       Sirsa - Hisar Passenger Special        04741                   Sirsa
# ...                                 ...          ...                     ...
# 5202    New Delhi Palwal Ladies Special        64492               NEW DELHI
# 5203     Visakhapatnam Rajahmundry Pass        67296           VISHAKAPATNAM
# 5204           Madgaon Karwar Passenger        70101                 MADGAON
# 5205            Danapur Giridih Express        83112                 DANAPUR
# 5206               Tribeni Link Express        84369             BARWADIH JN
#
#      destination  distance       total_time departure   arrival
# 0       UDHAMPUR      53.0  0 days 01:35:00  10:40:00  12:15:00
# 1       UDHAMPUR      53.0  0 days 01:35:00  16:15:00  17:50:00
# 2     JAMMU TAWI      53.0  0 days 01:30:00  18:20:00  19:50:00
# 3     BIKANER JN    1212.0  0 days 21:55:00  14:35:00  12:30:00
# 4          Hisar      82.0  0 days 01:35:00  22:50:00  00:25:00
# ...          ...       ...              ...       ...       ...
# 5202      PALWAL      56.0  0 days 01:30:00  17:50:00  19:20:00
# 5203  RAJAMUNDRY     201.0  0 days 05:15:00  18:10:00  23:25:00
# 5204      KARWAR      82.0  0 days 01:20:00  19:00:00  20:20:00
# 5205     Giridih     298.0  0 days 09:30:00  19:00:00  04:30:00
# 5206    BAREILLY     862.0  0 days 21:00:00  15:30:00  12:30:00
#
# [5207 rows x 8 columns]

# %%
td = pd.to_timedelta(data['total_time'])
data["total_minutes"] = td.dt.total_seconds()/60
data['total_minutes']
# Out:
# 0         95.0
# 1         95.0
# 2         90.0
# 3       1315.0
# 4         95.0
#          ...
# 5202      90.0
# 5203     315.0
# 5204      80.0
# 5205     570.0
# 5206    1260.0
# Name: total_minutes, Length: 5207, dtype: float64

# %%
# data = data.drop(columns=["total_time"])
