# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./datasets/ClassResult.csv")
data.sample(9)
# Out:
#     Unnamed: 0                Name       Roll No Program Branch  Semester  \
# 52          66   SUDHANSHU KUSHWAH  0403AL231067  B.Tech     AL         4
# 40          52      PRAYATN FATROD  0403AL231053  B.Tech     AL         4
# 20          26      HARSHIT RATHOD  0403AL231027  B.Tech     AL         4
# 43          55  RAJNANDINI CHOUHAN  0403AL231056  B.Tech     AL         4
# 45          58       ROHIT BHARGAV  0403AL231059  B.Tech     AL         4
# 23          29                 JAY  0403AL231030  B.Tech     AL         4
# 50          64      SHAILY RATHORE  0403AL231065  B.Tech     AL         4
# 19          24        HARIOM YADAV  0403AL231025  B.Tech     AL         4
# 10          14     DARSHAN KUSHWAH  0403AL231015  B.Tech     AL         4
#
#      Status    Session AL401- [T] AL402- [T] AL403- [P] AL404- [P] AL405- [P]  \
# 52  Regular  June-2025          C          B          B         C+          B
# ...

# %%
data.shape
# Out:
# (62, 17)

# %%
data["Semester"].value_counts()
# Out:
# Semester
# 4    62
# Name: count, dtype: int64

# %%
titanic = pd.read_csv('./datasets/titanic_data.csv')
titanic = titanic.drop(['Name', 'Ticket', 'Cabin'], axis=1)
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import BayesianRidge

# imputer = IterativeImputer(
#     estimator=BayesianRidge(),
#     max_iter=10,
#     random_state=42
# )

# imputed = imputer.fit_transform(titanic)
# titanic_new = pd.DataFrame(imputed, columns=titanic.columns)
# titanic_new


# lesson -- do encoding and then use iterative encoder as it works ONLY ON NUMERICAL VALUES.
